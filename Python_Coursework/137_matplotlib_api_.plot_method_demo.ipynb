# %%
import pandas as pd

# %%
transactions = pd.read_csv("../retail/transactions.csv", parse_dates=["date"])

transactions.head()
# Out:
#         date  store_nbr  transactions
# 0 2013-01-01         25           770
# 1 2013-01-02          1          2111
# 2 2013-01-02          2          2358
# 3 2013-01-02          3          3487
# 4 2013-01-02          4          1922

# %%
transactions.plot()
# Out:
# <Axes: >

# %%
transactions.set_index("date").loc["2013-01", "transactions"].plot()
# Out:
# <Axes: xlabel='date'>

# %%
transactions.query("store_nbr == 44").set_index("date").loc["2013-01", "transactions"].plot()
# Out:
# <Axes: xlabel='date'>

# %%
transactions.query("store_nbr == 44").set_index("date") # .loc["2013-01", "transactions"].plot()
# Out:
#             store_nbr  transactions
# date
# 2013-01-02         44          4821
# 2013-01-03         44          3618
# 2013-01-04         44          4169
# 2013-01-05         44          4921
# 2013-01-06         44          4925
# ...               ...           ...
# 2017-08-11         44          4418
# 2017-08-12         44          4277
# 2017-08-13         44          4392
# 2017-08-14         44          4039
# 2017-08-15         44          3815
#
# [1677 rows x 2 columns]

# %%
transactions_44 = transactions.loc[transactions["store_nbr"] == 44, ["date", "transactions"]]

transactions_44.head()
# Out:
#           date  transactions
# 38  2013-01-02          4821
# 84  2013-01-03          3618
# 130 2013-01-04          4169
# 176 2013-01-05          4921
# 222 2013-01-06          4925

# %%
transactions_44.set_index("date").plot()
# Out:
# <Axes: xlabel='date'>

# %%
transactions_44.plot(x="date", y="transactions")
# Out:
# <Axes: xlabel='date'>

# %%
(transactions
 # .query("store_nbr in [44, 47]")
 # .pivot_table(index="date", columns = "store_nbr")
 # .droplevel(0, axis=1)
 # .plot()
)
# Out:
#             date  store_nbr  transactions
# 0     2013-01-01         25           770
# 1     2013-01-02          1          2111
# 2     2013-01-02          2          2358
# 3     2013-01-02          3          3487
# 4     2013-01-02          4          1922
# ...          ...        ...           ...
# 83483 2017-08-15         50          2804
# 83484 2017-08-15         51          1573
# 83485 2017-08-15         52          2255
# 83486 2017-08-15         53           932
# 83487 2017-08-15         54           802
#
# [83488 rows x 3 columns]

# %%
(transactions
 .query("store_nbr in [44, 47]")
 # .pivot_table(index="date", columns = "store_nbr")
 # .droplevel(0, axis=1)
 # .plot()
)
# Out:
#             date  store_nbr  transactions
# 38    2013-01-02         44          4821
# 41    2013-01-02         47          4161
# 84    2013-01-03         44          3618
# 87    2013-01-03         47          3660
# 130   2013-01-04         44          4169
# ...          ...        ...           ...
# 83372 2017-08-13         47          3741
# 83423 2017-08-14         44          4039
# 83426 2017-08-14         47          3606
# 83477 2017-08-15         44          3815
# 83480 2017-08-15         47          3581
#
# [3354 rows x 3 columns]

# %%
(transactions
 .query("store_nbr in [44, 47]")
 .pivot_table(index="date", columns = "store_nbr")
 # .droplevel(0, axis=1)
 # .plot()
)
# Out:
#            transactions
# store_nbr            44      47
# date
# 2013-01-02       4821.0  4161.0
# 2013-01-03       3618.0  3660.0
# 2013-01-04       4169.0  3915.0
# 2013-01-05       4921.0  4764.0
# 2013-01-06       4925.0  4935.0
# ...                 ...     ...
# 2017-08-11       4418.0  4009.0
# 2017-08-12       4277.0  3825.0
# 2017-08-13       4392.0  3741.0
# 2017-08-14       4039.0  3606.0
# 2017-08-15       3815.0  3581.0
#
# [1677 rows x 2 columns]

# %%
(transactions
 .query("store_nbr in [44, 47]")
 .pivot_table(index="date", columns = "store_nbr")
 # .droplevel(0, axis=1)
 .plot()
)
# Out:
# <Axes: xlabel='date'>

# %%
(transactions
 .query("store_nbr in [44, 47]")
 .pivot_table(index="date", columns = "store_nbr")
 .droplevel(0, axis=1)
 .plot()
)
# Out:
# <Axes: xlabel='date'>

# %%
(transactions
 .query("store_nbr in [44, 47]")
 .pivot_table(index="date", columns = "store_nbr")
 .droplevel(0, axis=1)
 .plot()
);
