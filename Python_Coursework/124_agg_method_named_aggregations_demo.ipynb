# %%
import pandas as pd

# %%
premier_league = pd.read_excel('../project_data/premier_league_games_full.xlsx')

# %%
premier_league.head()
# Out:
#      id             league_name     season           HomeTeam  \
# 0  1729  England Premier League  2008/2009  Manchester United
# 1  1730  England Premier League  2008/2009            Arsenal
# 2  1731  England Premier League  2008/2009         Sunderland
# 3  1732  England Premier League  2008/2009    West Ham United
# 4  1733  England Premier League  2008/2009        Aston Villa
#
#                AwayTeam  HomeGoals  AwayGoals
# 0      Newcastle United          1          1
# 1  West Bromwich Albion          1          0
# 2             Liverpool          0          1
# 3        Wigan Athletic          2          1
# 4       Manchester City          4          2

# %%
(premier_league
 .groupby(["season", "HomeTeam"], as_index=False)
 .agg("sum"))
# Out:
#         season              HomeTeam     id  \
# 0    2008/2009               Arsenal  36128
# 1    2008/2009           Aston Villa  36136
# 2    2008/2009      Blackburn Rovers  36781
# 3    2008/2009      Bolton Wanderers  36214
# 4    2008/2009               Chelsea  36552
# ..         ...                   ...    ...
# 155  2015/2016          Swansea City  87241
# 156  2015/2016     Tottenham Hotspur  87218
# 157  2015/2016               Watford  87142
# 158  2015/2016  West Bromwich Albion  87064
# 159  2015/2016       West Ham United  86965
#
#                                            league_name  \
# 0    England Premier LeagueEngland Premier LeagueEn...
# 1    England Premier LeagueEngland Premier LeagueEn...
# 2    England Premier LeagueEngland Premier LeagueEn...
# 3    England Premier LeagueEngland Premier LeagueEn...
# 4    England Premier LeagueEngland Premier LeagueEn...
# ..                                                 ...
# 155  England Premier LeagueEngland Premier LeagueEn...
# 156  England Premier LeagueEngland Premier LeagueEn...
# 157  England Premier LeagueEngland Premier LeagueEn...
# 158  England Premier LeagueEngland Premier LeagueEn...
# 159  England Premier LeagueEngland Premier LeagueEn...
#
#                                               AwayTeam  HomeGoals  AwayGoals
# 0    West Bromwich AlbionTottenham HotspurMancheste...         31         16
# 1    Manchester CityBlackburn RoversMiddlesbroughMa...         27         21
# 2    ChelseaSunderlandLiverpoolStoke CityHull CityM...         22         23
# 3    Stoke CityEvertonManchester CityLiverpoolChels...         21         21
# 4    PortsmouthSunderlandNewcastle UnitedArsenalWes...         33         12
# ..                                                 ...        ...        ...
# 155  ArsenalBournemouthLeicester CityWest Ham Unite...         20         20
# 156  Aston VillaWest Ham UnitedChelseaNewcastle Uni...         35         15
# 157  West Ham UnitedManchester UnitedNorwich CityLi...         20         19
# 158  Manchester CityLeicester CityArsenalTottenham ...         20         26
# 159  ChelseaEvertonWest Bromwich AlbionStoke CitySo...         34         26
#
# [160 rows x 7 columns]

# %%
(premier_league
 .groupby(["season", "HomeTeam"], as_index=False)
 .agg(["sum", "mean"]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Desktop/projects/Data_Analysis_with_Python_NumPy_and_Pandas/venv/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~/Desktop/projects/Data_Analysis_with_Python_NumPy_and_Pandas/venv/lib/python3.11/site-packages/pandas/core/groupby/ops.py:863, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     861     preserve_dtype = True
# --> 863 result = self._aggregate_series_pure_python(obj, func)
#     865 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~/Desktop/projects/Data_Analysis_with_Python_NumPy_and_Pandas/venv/lib/python3.11/site-packages/pandas/core/groupby/ops.py:884, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     883 for i, group in enumerate(splitter):
# --> 884     res = func(group)
#     885     res = extract_result(res)
#
# File ~/Desktop/projects/Data_Analysis_with_Python_NumPy_and_Pandas/venv/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:2454, in GroupBy.mean.<locals>.<lambda>(x)
#    2451 else:
#    2452     result = self._cython_agg_general(
#    2453         "mean",
# -> 2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File ~/Desktop/projects/Data_Analysis_with_Python_NumPy_and_Pandas/venv/lib/python3.11/site-packages/pandas/core/series.py:6529, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6521 @doc(make_doc("mean", ndim=1))
#    6522 def mean(
#    6523     self,
#    (...)
#    6527     **kwargs,
#    6528 ):
# -> 6529     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~/Desktop/projects/Data_Analysis_with_Python_NumPy_and_Pandas/venv/lib/python3.11/site-packages/pandas/core/generic.py:12413, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12406 def mean(
#   12407     self,
#   12408     axis: Axis | None = 0,
#    (...)
#   12411     **kwargs,
#   12412 ) -> Series | float:
# > 12413     return self._stat_function(
#   12414         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12415     )
#
# File ~/Desktop/projects/Data_Analysis_with_Python_NumPy_and_Pandas/venv/lib/python3.11/site-packages/pandas/core/generic.py:12370, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12368 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12370 return self._reduce(
#   12371     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12372 )
#
# File ~/Desktop/projects/Data_Analysis_with_Python_NumPy_and_Pandas/venv/lib/python3.11/site-packages/pandas/core/series.py:6437, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6433     raise TypeError(
#    6434         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6435         "with non-numeric dtypes."
#    6436     )
# -> 6437 return op(delegate, skipna=skipna, **kwds)
#
# File ~/Desktop/projects/Data_Analysis_with_Python_NumPy_and_Pandas/venv/lib/python3.11/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~/Desktop/projects/Data_Analysis_with_Python_NumPy_and_Pandas/venv/lib/python3.11/site-packages/pandas/core/nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File ~/Desktop/projects/Data_Analysis_with_Python_NumPy_and_Pandas/venv/lib/python3.11/site-packages/pandas/core/nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File ~/Desktop/projects/Data_Analysis_with_Python_NumPy_and_Pandas/venv/lib/python3.11/site-packages/pandas/core/nanops.py:1701, in _ensure_numeric(x)
#    1699 if isinstance(x, str):
#    1700     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702 try:
#
# TypeError: Could not convert string 'England Premier LeagueEngland Premier LeagueEngland Premier LeagueEngland Premier LeagueEngland Premier LeagueEngland Premier LeagueEngland Premier LeagueEngland Premier LeagueEngland Premier LeagueEngland Premier LeagueEngland Premier LeagueEngland Premier LeagueEngland Premier LeagueEngland Premier LeagueEngland Premier LeagueEngland Premier LeagueEngland Premier LeagueEngland Premier LeagueEngland Premier League' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 (premier_league
#       2  .groupby(["season", "HomeTeam"], as_index=False)
# ----> 3  .agg(["sum", "mean"]))
#
# File ~/Desktop/projects/Data_Analysis_with_Python_NumPy_and_Pandas/venv/lib/python3.11/site-packages/pandas/core/groupby/generic.py:1432, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1429     kwargs["engine_kwargs"] = engine_kwargs
#    1431 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1432 result = op.agg()
#    1433 if not is_dict_like(func) and result is not None:
#    1434     # GH #52849
#    1435     if not self.as_index and is_list_like(func):
#
# File ~/Desktop/projects/Data_Analysis_with_Python_NumPy_and_Pandas/venv/lib/python3.11/site-packages/pandas/core/apply.py:193, in Apply.agg(self)
#     190     return self.agg_dict_like()
#     191 elif is_list_like(func):
#     192     # we require a list, but not a 'str'
# --> 193     return self.agg_list_like()
#     195 if callable(func):
#     196     f = com.get_cython_func(func)
#
# File ~/Desktop/projects/Data_Analysis_with_Python_NumPy_and_Pandas/venv/lib/python3.11/site-packages/pandas/core/apply.py:326, in Apply.agg_list_like(self)
#     318 def agg_list_like(self) -> DataFrame | Series:
#     319     """
#     320     Compute aggregation in the case of a list-like argument.
#     321
#    (...)
#     324     Result of aggregation.
#     325     """
# --> 326     return self.agg_or_apply_list_like(op_name="agg")
#
# File ~/Desktop/projects/Data_Analysis_with_Python_NumPy_and_Pandas/venv/lib/python3.11/site-packages/pandas/core/apply.py:1571, in GroupByApply.agg_or_apply_list_like(self, op_name)
#    1566 # Only set as_index=True on groupby objects, not Window or Resample
#    1567 # that inherit from this class.
#    1568 with com.temp_setattr(
#    1569     obj, "as_index", True, condition=hasattr(obj, "as_index")
#    1570 ):
# -> 1571     keys, results = self.compute_list_like(op_name, selected_obj, kwargs)
#    1572 result = self.wrap_results_list_like(keys, results)
#    1573 return result
#
# File ~/Desktop/projects/Data_Analysis_with_Python_NumPy_and_Pandas/venv/lib/python3.11/site-packages/pandas/core/apply.py:385, in Apply.compute_list_like(self, op_name, selected_obj, kwargs)
#     379 colg = obj._gotitem(col, ndim=1, subset=selected_obj.iloc[:, index])
#     380 args = (
#     381     [self.axis, *self.args]
#     382     if include_axis(op_name, colg)
#     383     else self.args
#     384 )
# --> 385 new_res = getattr(colg, op_name)(func, *args, **kwargs)
#     386 results.append(new_res)
#     387 indices.append(index)
#
# File ~/Desktop/projects/Data_Analysis_with_Python_NumPy_and_Pandas/venv/lib/python3.11/site-packages/pandas/core/groupby/generic.py:257, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     255 kwargs["engine"] = engine
#     256 kwargs["engine_kwargs"] = engine_kwargs
# --> 257 ret = self._aggregate_multiple_funcs(func, *args, **kwargs)
#     258 if relabeling:
#     259     # columns is not narrowed by mypy from relabeling flag
#     260     assert columns is not None  # for mypy
#
# File ~/Desktop/projects/Data_Analysis_with_Python_NumPy_and_Pandas/venv/lib/python3.11/site-packages/pandas/core/groupby/generic.py:362, in SeriesGroupBy._aggregate_multiple_funcs(self, arg, *args, **kwargs)
#     360     for idx, (name, func) in enumerate(arg):
#     361         key = base.OutputKey(label=name, position=idx)
# --> 362         results[key] = self.aggregate(func, *args, **kwargs)
#     364 if any(isinstance(x, DataFrame) for x in results.values()):
#     365     from pandas import concat
#
# File ~/Desktop/projects/Data_Analysis_with_Python_NumPy_and_Pandas/venv/lib/python3.11/site-packages/pandas/core/groupby/generic.py:249, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     247     if engine_kwargs is not None:
#     248         kwargs["engine_kwargs"] = engine_kwargs
# --> 249     return getattr(self, func)(*args, **kwargs)
#     251 elif isinstance(func, abc.Iterable):
#     252     # Catch instances of lists / tuples
#     253     # but not the class list / tuple itself.
#     254     func = maybe_mangle_lambdas(func)
#
# File ~/Desktop/projects/Data_Analysis_with_Python_NumPy_and_Pandas/venv/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:2452, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2445     return self._numba_agg_general(
#    2446         grouped_mean,
#    2447         executor.float_dtype_mapping,
#    2448         engine_kwargs,
#    2449         min_periods=0,
#    2450     )
#    2451 else:
# -> 2452     result = self._cython_agg_general(
#    2453         "mean",
#    2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File ~/Desktop/projects/Data_Analysis_with_Python_NumPy_and_Pandas/venv/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1998, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1995     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996     return result
# -> 1998 new_mgr = data.grouped_reduce(array_func)
#    1999 res = self._wrap_agged_manager(new_mgr)
#    2000 if how in ["idxmin", "idxmax"]:
#
# File ~/Desktop/projects/Data_Analysis_with_Python_NumPy_and_Pandas/venv/lib/python3.11/site-packages/pandas/core/internals/base.py:367, in SingleDataManager.grouped_reduce(self, func)
#     365 def grouped_reduce(self, func):
#     366     arr = self.array
# --> 367     res = func(arr)
#     368     index = default_index(len(res))
#     370     mgr = type(self).from_array(res, index)
#
# File ~/Desktop/projects/Data_Analysis_with_Python_NumPy_and_Pandas/venv/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1995, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1992     return result
#    1994 assert alt is not None
# -> 1995 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996 return result
#
# File ~/Desktop/projects/Data_Analysis_with_Python_NumPy_and_Pandas/venv/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1946, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1944     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1945     # preserve the kind of exception that raised
# -> 1946     raise type(err)(msg) from err
#    1948 if ser.dtype == object:
#    1949     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->mean,dtype->object]

# %%
(premier_league
 .groupby(["season", "HomeTeam"], as_index=False)
 .agg(["sum", "count"]))
# Out:
#         season              HomeTeam     id        \
#                                         sum count
# 0    2008/2009               Arsenal  36128    19
# 1    2008/2009           Aston Villa  36136    19
# 2    2008/2009      Blackburn Rovers  36781    19
# 3    2008/2009      Bolton Wanderers  36214    19
# 4    2008/2009               Chelsea  36552    19
# ..         ...                   ...    ...   ...
# 155  2015/2016          Swansea City  87241    19
# 156  2015/2016     Tottenham Hotspur  87218    19
# 157  2015/2016               Watford  87142    19
# 158  2015/2016  West Bromwich Albion  87064    19
# 159  2015/2016       West Ham United  86965    19
#
#                                            league_name        \
#                                                    sum count
# 0    England Premier LeagueEngland Premier LeagueEn...    19
# 1    England Premier LeagueEngland Premier LeagueEn...    19
# 2    England Premier LeagueEngland Premier LeagueEn...    19
# 3    England Premier LeagueEngland Premier LeagueEn...    19
# 4    England Premier LeagueEngland Premier LeagueEn...    19
# ..                                                 ...   ...
# 155  England Premier LeagueEngland Premier LeagueEn...    19
# 156  England Premier LeagueEngland Premier LeagueEn...    19
# 157  England Premier LeagueEngland Premier LeagueEn...    19
# 158  England Premier LeagueEngland Premier LeagueEn...    19
# 159  England Premier LeagueEngland Premier LeagueEn...    19
#
#                                               AwayTeam       HomeGoals        \
#                                                    sum count       sum count
# 0    West Bromwich AlbionTottenham HotspurMancheste...    19        31    19
# 1    Manchester CityBlackburn RoversMiddlesbroughMa...    19        27    19
# 2    ChelseaSunderlandLiverpoolStoke CityHull CityM...    19        22    19
# 3    Stoke CityEvertonManchester CityLiverpoolChels...    19        21    19
# 4    PortsmouthSunderlandNewcastle UnitedArsenalWes...    19        33    19
# ..                                                 ...   ...       ...   ...
# 155  ArsenalBournemouthLeicester CityWest Ham Unite...    19        20    19
# 156  Aston VillaWest Ham UnitedChelseaNewcastle Uni...    19        35    19
# 157  West Ham UnitedManchester UnitedNorwich CityLi...    19        20    19
# 158  Manchester CityLeicester CityArsenalTottenham ...    19        20    19
# 159  ChelseaEvertonWest Bromwich AlbionStoke CitySo...    19        34    19
#
#     AwayGoals
#           sum count
# 0          16    19
# 1          21    19
# 2          23    19
# 3          21    19
# 4          12    19
# ..        ...   ...
# 155        20    19
# 156        15    19
# 157        19    19
# 158        26    19
# 159        26    19
#
# [160 rows x 12 columns]

# %%
(premier_league
 .groupby(["season", "HomeTeam"], as_index=False)
 .agg({"HomeGoals": ["sum", "mean"],
       "AwayGoals": ["sum", "sum"]}))
# Out:
#         season              HomeTeam HomeGoals           AwayGoals
#                                            sum      mean       sum sum
# 0    2008/2009               Arsenal        31  1.631579        16  16
# 1    2008/2009           Aston Villa        27  1.421053        21  21
# 2    2008/2009      Blackburn Rovers        22  1.157895        23  23
# 3    2008/2009      Bolton Wanderers        21  1.105263        21  21
# 4    2008/2009               Chelsea        33  1.736842        12  12
# ..         ...                   ...       ...       ...       ...  ..
# 155  2015/2016          Swansea City        20  1.052632        20  20
# 156  2015/2016     Tottenham Hotspur        35  1.842105        15  15
# 157  2015/2016               Watford        20  1.052632        19  19
# 158  2015/2016  West Bromwich Albion        20  1.052632        26  26
# 159  2015/2016       West Ham United        34  1.789474        26  26
#
# [160 rows x 6 columns]

# %%
(premier_league
 .groupby(["season", "HomeTeam"], as_index=False)
 .agg(home_goal_sum = ("HomeGoals", "sum"),
      away_goal_sum = ("AwayGoals", "sum")))
# Out:
#         season              HomeTeam  home_goal_sum  away_goal_sum
# 0    2008/2009               Arsenal             31             16
# 1    2008/2009           Aston Villa             27             21
# 2    2008/2009      Blackburn Rovers             22             23
# 3    2008/2009      Bolton Wanderers             21             21
# 4    2008/2009               Chelsea             33             12
# ..         ...                   ...            ...            ...
# 155  2015/2016          Swansea City             20             20
# 156  2015/2016     Tottenham Hotspur             35             15
# 157  2015/2016               Watford             20             19
# 158  2015/2016  West Bromwich Albion             20             26
# 159  2015/2016       West Ham United             34             26
#
# [160 rows x 4 columns]
