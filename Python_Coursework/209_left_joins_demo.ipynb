# %%
import pandas as pd

# %%
transactions = pd.read_csv("../retail/transactions.csv", parse_dates=["date"])

oil = pd.read_csv("../retail/oil.csv", parse_dates=["date"])

# %%
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83488 entries, 0 to 83487
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          83488 non-null  datetime64[ns]
#  1   store_nbr     83488 non-null  int64
#  2   transactions  83488 non-null  int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 1.9 MB

# %%
oil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1218 non-null   datetime64[ns]
#  1   dcoilwtico  1175 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 19.2 KB

# %%
transactions.merge(oil,
                   how="left",
                   # left_on=["date"],
                   # right_on=["date"]
                  )# .loc[transactions["date"] == '2013-01-06']
# Out:
#             date  store_nbr  transactions  dcoilwtico
# 0     2013-01-01         25           770         NaN
# 1     2013-01-02          1          2111       93.14
# 2     2013-01-02          2          2358       93.14
# 3     2013-01-02          3          3487       93.14
# 4     2013-01-02          4          1922       93.14
# ...          ...        ...           ...         ...
# 83483 2017-08-15         50          2804       47.57
# 83484 2017-08-15         51          1573       47.57
# 83485 2017-08-15         52          2255       47.57
# 83486 2017-08-15         53           932       47.57
# 83487 2017-08-15         54           802       47.57
#
# [83488 rows x 4 columns]

# %%
transactions.merge(oil,
                   how="left",
                   left_on=["date"],
                   right_on=["date"]
                  )# .loc[transactions["date"] == '2013-01-06']
# Out:
#             date  store_nbr  transactions  dcoilwtico
# 0     2013-01-01         25           770         NaN
# 1     2013-01-02          1          2111       93.14
# 2     2013-01-02          2          2358       93.14
# 3     2013-01-02          3          3487       93.14
# 4     2013-01-02          4          1922       93.14
# ...          ...        ...           ...         ...
# 83483 2017-08-15         50          2804       47.57
# 83484 2017-08-15         51          1573       47.57
# 83485 2017-08-15         52          2255       47.57
# 83486 2017-08-15         53           932       47.57
# 83487 2017-08-15         54           802       47.57
#
# [83488 rows x 4 columns]

# %%
transactions.merge(oil,
                   how="left",
                   left_on=["date"],
                   right_on=["date"]
                  ).loc[transactions["date"] == '2013-01-06']
# Out:
#           date  store_nbr  transactions  dcoilwtico
# 185 2013-01-06          1           520         NaN
# 186 2013-01-06          2          1992         NaN
# 187 2013-01-06          3          3590         NaN
# 188 2013-01-06          4          1891         NaN
# 189 2013-01-06          5          1754         NaN
# 190 2013-01-06          6          2313         NaN
# 191 2013-01-06          7          1431         NaN
# 192 2013-01-06          8          2748         NaN
# 193 2013-01-06          9          2635         NaN
# 194 2013-01-06         10          1173         NaN
# 195 2013-01-06         11          3188         NaN
# 196 2013-01-06         12          1271         NaN
# 197 2013-01-06         13          1008         NaN
# 198 2013-01-06         14          1313         NaN
# 199 2013-01-06         15          1149         NaN
# 200 2013-01-06         16          1323         NaN
# 201 2013-01-06         17          1383         NaN
# 202 2013-01-06         18          1405         NaN
# 203 2013-01-06         19          1157         NaN
# 204 2013-01-06         23          1100         NaN
# 205 2013-01-06         24          2061         NaN
# 206 2013-01-06         25           716         NaN
# 207 2013-01-06         26          1075         NaN
# 208 2013-01-06         27          1614         NaN
# 209 2013-01-06         28          1207         NaN
# 210 2013-01-06         30           667         NaN
# 211 2013-01-06         31          1468         NaN
# 212 2013-01-06         32           772         NaN
# 213 2013-01-06         33          1302         NaN
# 214 2013-01-06         34          2377         NaN
# 215 2013-01-06         35           651         NaN
# 216 2013-01-06         37          1282         NaN
# 217 2013-01-06         38          2522         NaN
# 218 2013-01-06         39          1571         NaN
# 219 2013-01-06         40          1023         NaN
# 220 2013-01-06         41          1142         NaN
# 221 2013-01-06         43          1194         NaN
# 222 2013-01-06         44          4925         NaN
# 223 2013-01-06         45          4418         NaN
# 224 2013-01-06         46          5401         NaN
# 225 2013-01-06         47          4935         NaN
# 226 2013-01-06         48          4591         NaN
# 227 2013-01-06         49          2795         NaN
# 228 2013-01-06         50          3297         NaN
# 229 2013-01-06         51          1934         NaN
# 230 2013-01-06         54          1180         NaN

# %%
transactions.merge(oil,
                   how="outer",
                   left_on=["date"],
                   right_on=["date"]
                  )
# Out:
#             date  store_nbr  transactions  dcoilwtico
# 0     2013-01-01       25.0         770.0         NaN
# 1     2013-01-02        1.0        2111.0       93.14
# 2     2013-01-02        2.0        2358.0       93.14
# 3     2013-01-02        3.0        3487.0       93.14
# 4     2013-01-02        4.0        1922.0       93.14
# ...          ...        ...           ...         ...
# 83499 2017-08-25        NaN           NaN       47.65
# 83500 2017-08-28        NaN           NaN       46.40
# 83501 2017-08-29        NaN           NaN       46.46
# 83502 2017-08-30        NaN           NaN       45.96
# 83503 2017-08-31        NaN           NaN       47.26
#
# [83504 rows x 4 columns]

# %%
oil.tail()
# Out:
#            date  dcoilwtico
# 1213 2017-08-25       47.65
# 1214 2017-08-28       46.40
# 1215 2017-08-29       46.46
# 1216 2017-08-30       45.96
# 1217 2017-08-31       47.26

# %%
transactions.tail()
# Out:
#             date  store_nbr  transactions
# 83483 2017-08-15         50          2804
# 83484 2017-08-15         51          1573
# 83485 2017-08-15         52          2255
# 83486 2017-08-15         53           932
# 83487 2017-08-15         54           802
