# %%
import pandas as pd

# %%
transactions = pd.read_csv("../retail/transactions.csv", parse_dates=["date"])

transactions.head()
# Out:
#         date  store_nbr  transactions
# 0 2013-01-01         25           770
# 1 2013-01-02          1          2111
# 2 2013-01-02          2          2358
# 3 2013-01-02          3          3487
# 4 2013-01-02          4          1922

# %%
transactions.plot()
# Out:
# <Axes: >

# %%
transactions.set_index("date").loc["2013-01", "transactions"].plot()
# Out:
# <Axes: xlabel='date'>

# %%
transactions.query("store_nbr == 44").set_index("date").loc["2013-01", "transactions"].plot()
# Out:
# <Axes: xlabel='date'>

# %%
transactions.query("store_nbr == 44").set_index("date") # .loc["2013-01", "transactions"].plot()
# Out:
#             store_nbr  transactions
# date
# 2013-01-02         44          4821
# 2013-01-03         44          3618
# 2013-01-04         44          4169
# 2013-01-05         44          4921
# 2013-01-06         44          4925
# ...               ...           ...
# 2017-08-11         44          4418
# 2017-08-12         44          4277
# 2017-08-13         44          4392
# 2017-08-14         44          4039
# 2017-08-15         44          3815
#
# [1677 rows x 2 columns]

# %%
transactions_44 = transactions.loc[transactions["store_nbr"] == 44, ["date", "transactions"]]

transactions_44.head()
# Out:
#           date  transactions
# 38  2013-01-02          4821
# 84  2013-01-03          3618
# 130 2013-01-04          4169
# 176 2013-01-05          4921
# 222 2013-01-06          4925

# %%
transactions_44.set_index("date").plot(
    title="Store 44 Transaction 2013-2017")
# Out:
# <Axes: title={'center': 'Store 44 Transaction 2013-2017'}, xlabel='date'>

# %%
transactions_44.set_index("date").plot(
    title="Store 44 Transaction 2013-2017",
    xlabel='Year')
# Out:
# <Axes: title={'center': 'Store 44 Transaction 2013-2017'}, xlabel='Year'>

# %%
transactions_44.set_index("date").plot(
    title = "Store 44 Transaction 2013-2017",
    xlabel = 'Date',
    ylabel = "Daily Transactions"
)
# Out:
# <Axes: title={'center': 'Store 44 Transaction 2013-2017'}, xlabel='Date', ylabel='Daily Transactions'>

# %%
transactions_44.set_index("date").plot(
    # title = "Store 44 Transaction 2013-2017",
    # xlabel = 'Date',
    # ylabel = "Daily Transactions"
)
# Out:
# <Axes: xlabel='date'>
